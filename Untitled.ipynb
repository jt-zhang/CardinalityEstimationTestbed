# %%
import pandas as pd
import numpy as np

version = 'cols_4_distinct_1000_corr_6_skew_6'
table = pd.read_csv('./Synthetic/csvdata_sql/' + version + '.csv').apply(lambda x: (x - np.min(x)) / (np.max(x) - np.min(x)))
sample = table.sample(n=20000).values.tolist()

# %%
sample
# Out:
# [[0.031031031031031032,
#   0.031031031031031032,
#   0.025025025025025027,
#   0.42742742742742745],
#  [0.3793793793793794,
#   0.28428428428428426,
#   0.036036036036036036,
#   0.6546546546546547],
#  [0.0970970970970971,
#   0.12612612612612611,
#   0.0970970970970971,
#   0.0970970970970971],
#  [0.3883883883883884,
#   0.3883883883883884,
#   0.9769769769769769,
#   0.4174174174174174],
#  [0.4974974974974975,
#   0.2992992992992993,
#   0.9109109109109109,
#   0.003003003003003003],
#  [0.5515515515515516,
#   0.7927927927927928,
#   0.08208208208208208,
#   0.972972972972973],
#  [0.5175175175175175,
#   0.5175175175175175,
#   0.8858858858858859,
#   0.5945945945945946],
#  [0.16116116116116116,
#   0.16116116116116116,
#   0.1021021021021021,
#   0.026026026026026026],
#  [0.11411411411411411,
#   0.33633633633633636,
#   0.044044044044044044,
#   0.01901901901901902],
#  [0.39039039039039036,
#   0.39039039039039036,
#   0.35535535535535534,
#   0.5385385385385385],
# ...

# %%
table
# Out:
#            col0      col1      col2      col3
# 0      0.000000  0.000000  0.000000  0.523524
# 1      0.001001  0.001001  0.001001  0.640641
# 2      0.002002  0.002002  0.198198  0.002002
# 3      0.003003  0.003003  0.127127  0.448448
# 4      0.004004  0.004004  0.691692  0.004004
# ...         ...       ...       ...       ...
# 99995  0.097097  0.196196  0.090090  0.123123
# 99996  0.856857  0.709710  0.596597  0.352352
# 99997  0.668669  0.668669  0.978979  0.138138
# 99998  0.112112  0.225225  0.013013  0.418418
# 99999  0.380380  0.548549  0.441441  0.106106
#
# [100000 rows x 4 columns]
